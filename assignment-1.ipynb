# %%
# explain the key features of Python that make it a popular choice for programming
#ANS

#1. Simple and Readable Syntax
# - Simplified code, it is great for new programmers

#2. High-Level Language
# - Omits computationally intensive details and directs the audience’s attention to the solved problem

#3. Interpreted Language
# - Runs the code line by line which helps in debugging

#4. Dynamically Typed
# - No declaration required for variables due to which there is no need for type declaration also as the type is determined at runtime

#5. Extensive Standard Library
# - Somewhat a rich library with many modules for different operations thus eliminating the need to program them from scratch

#6. Cross-Platform Compatibility
# - It is compatible with file systems of different operating systems without the need for a new code rewrite

#7. Large Community and Support
# - This includes goals of having many resources available, and documented and well supported by the community

#8. Integration Capabilities
# - The completion of integration is relatively easy with other languages and technologies

#9. Popular 
# - Popular in such industries as web development, data analysis, artificial intelligence, automation, and many others

# %%
# Describe the role of predefined keywords in Python and provide examples of how they are used in a program
#ANS

# The predefined keywords in Python basically refer to arrays of characters having predefined specific functions in the language
# They cannot be used as identifiers (variable names, function names) because they are the language keywords
# Python programming language uses these keywords to shape the sequence and control of commands within a program

# if, elif, else -
# x = 10
# if x > 0:
#     print("Positive")
# elif x == 0:
#     print("Zero")
# else:
#     print("Negative")

# %%
#Compare and contrast mutable and immutable objects in Python with examples
#ANS

# Mutable Objects:
# It has the feature of change after being made as opposed to fixed objects which cannot be altered in any way once they have been made
# They include lists, dictionary, sets, etc., byte arrays
# This means that any changes made to the objects are immediately visible or reflected in all callers or users of those objects

# my_list = [1, 2, 3]
# print(my_list)  
# my_list.append(4)
# print(my_list)  
# Output: [1, 2, 3, 4]

# Immutable Objects:
# It is not possible to alter an immutable object once it has been designed and developed
# They include integers, floating numbers, string, tuples, and frozensets
# When an immutable object is changed then the result is a formation of a new object but not altering the earlier object

# my_str = "hello"
# print(my_str)  
# new_str = my_str.replace('h', 'j')
# print(my_str) 
# print(new_str) 
# Output: hello
# Output: jello

# %%
#Discuss the different types of operators in Python and provide examples of how they are used
#ANS

# Arithmetic Operators:
# Used for mathematical calculations
# a = 10
# b = 5
# print(a + b)  # Addition: 15
# print(a - b)  # Subtraction: 5
# print(a * b)  # Multiplication: 50
# print(a / b)  # Division: 2.0
# print(a % b)  # Modulus: 0
# print(a ** b) # Exponentiation: 100000
# print(a // b) # Floor Division: 2

# Comparison Operators:
# Used to compare two values
# a = 10
# b = 5
# print(a == b)  # Equal to: False
# print(a != b)  # Not equal to: True
# print(a > b)   # Greater than: True
# print(a < b)   # Less than: False
# print(a >= b)  # Greater than or equal to: True
# print(a <= b)  # Less than or equal to: False

# Assignment Operators:
# Used to assign values to variables
# a = 10
# b = 5
# a += b 
# print(a)  # 15
# a -= b  
# print(a)  # 10
# a *= b 
# print(a)  # 50
# a /= b  
# print(a)  # 10.0
# a %= b 
# print(a)  # 0.0
# a **= b 
# print(a)  # 0.0
# a //= b 
# print(a)  # 0.0

# Logical Operators:
# Used to combine conditional statements
# a = True
# b = False
# print(a and b)  #  False
# print(a or b)   # True
# print(not a)    #  False

# Bitwise Operators:
# Used to perform bit-level operations
# a = 10        #  1010
# b = 4         #  0100
# print(a & b)  #  0 
# print(a | b)  #  14 
# print(a ^ b)  #  14 
# print(~a)     #  -11 
# print(a << 2) #  40 
# print(a >> 2) #  2 

# Identity Operators:
# Used to compare the memory location of two objects
# a = 10
# b = 10
# print(a is b) # True

# Membership Operators:
# Used to test if a sequence contains a certain value
# a = [1, 2, 3, 4, 5]
# print(3 in a)   # True

# %%
#Explain the concept of type casting in Python with examples
#ANS

# Type casting or type conversion in Python means to change the data type of the given variable
# This is followed when one is adding, subtracting, multiplying or dividing different data types 
# or if one wants the data to be in a certain format 
# The programming language Python offers a number of integrated functions for type conversion

# Examples:
#s1 = "123.45"
#s2 = "71"
#i = 42
#f = 3.14
#t = (1, 2, 3)
#l = [4, 5, 6]
#s = {7, 8, 9}

# Convert string to integer
# i2 = int(s2)
# print(f"Converted {s2} to integer: {i2}")

# Convert string to float
# f2 = float(s1)
# print(f"Converted {s1} to float: {f2}")

# Convert list to tuple
# t2 = tuple(l)
# print(f"Converted list {l} to tuple: {t2}")

# Convert tuple to set
# s2 = set(t)
# print(f"Converted tuple {t} to set: {s2}")

# Convert set to list
# lst2 = list(s)
# print(f"Converted set {s} to list: {lst2}")

# Convert list to set
# s3 = set(l)
# print(f"Converted list {l} to set: {s3}")

# %%
#How do conditional statements work in Python? Illustrate with examples
#ANS

# Conditional statements are used to permit only specific lines of code to be executed if some conditions are met
# They determine the direction of the program since they make decisions
# There are mainly three conditional statements in Python, which are if, elif, and else.

# if Statement:
# x = 10
# if x > 5:
#     print("x is greater than 5")

# if-else Statement:  
# x = 3
# if x > 5:
#     print("x is greater than 5")
# else:
#     print("x is not greater than 5")

# if-elif-else Statement:    
# x = 7
# if x > 10:
#     print("x is greater than 10")
# elif x > 5:
#     print("x is greater than 5 but not greater than 10")
# else:
#     print("x is 5 or less")
    
# Nested if Statements:
# x = 8
# if x > 5:
#     if x < 10:
#         print("x is between 5 and 10")
#     else:
#         print("x is 10 or more")
# else:
#     print("x is 5 or less")

# %%
#Describe the different types of loops in Python and their use cases with examples
#ANS

# for Loop:
# Used to iterate over a sequence (such as a list, tuple, string, or range) and execute a block of code for each item in the sequence
# Use Cases:
# - Iterating over items in a list or tuple
# - Iterating over characters in a string
# - Repeating an action a specific number of times

# fruits = ['apple', 'banana', 'cherry']
# for fruit in fruits:
#     print(fruit)

# while Loop:
# Repeats a block of code as long as a specified condition is true
# Use Cases:
# - Repeating actions until a certain condition changes

# count = 0
# while count < 5:
#     print(count)
#     count += 1

# break:
# Exits the loop prematurely, regardless of the loop’s condition

# for i in range(10):
#     if i == 5:
#         break
#     print(i)

# continue:
# Skips the rest of the code inside the loop for the current iteration and proceeds with the next iteration

# for i in range(5):
#     if i == 2:
#         continue
#     print(i)
